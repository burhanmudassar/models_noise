# %% [markdown]
# # Object Detection Demo
# Welcome to the object detection inference walkthrough!  This notebook will walk you step by step through the process of using a pre-trained model to detect objects in an image. Make sure to follow the [installation instructions](https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/installation.md) before you start.

# %% [markdown]
# # Imports

# %%
import numpy as np
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile

from collections import defaultdict
from io import StringIO
from matplotlib import pyplot as plt
from PIL import Image

if tf.__version__ != '1.4.0':
  raise ImportError('Please upgrade your tensorflow installation to v1.4.0!')
# Out:
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## Env setup

# %%
# This is needed to display the images.
# %matplotlib inline

# This is needed since the notebook is stored in the object_detection folder.
sys.path.append("..")

# %% [markdown]
# ## Object detection imports
# Here are the imports from the object detection module.

# %%
from utils import label_map_util

from utils import visualization_utils as vis_util

# %% [markdown]
# # Model preparation

# %% [markdown]
# ## Variables
#
# Any model exported using the `export_inference_graph.py` tool can be loaded here simply by changing `PATH_TO_CKPT` to point to a new .pb file.
#
# By default we use an "SSD with Mobilenet" model here. See the [detection model zoo](https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/detection_model_zoo.md) for a list of other models that can be run out-of-the-box with varying speeds and accuracies.

# %%
# What model to download.
#MODEL_NAME = 'ssd_mobilenet_v1_coco_2017_11_08'
#MODEL_NAME = 'inference_graph/rfcn_resnet101_coco_pivot'
MODEL_NAME = 'inference_graph/faster_rcnn_inception_v2_coco'
MODEL_FILE = MODEL_NAME + '.tar.gz'
DOWNLOAD_BASE = 'http://download.tensorflow.org/models/object_detection/'

# Path to frozen detection graph. This is the actual model that is used for the object detection.
PATH_TO_CKPT = MODEL_NAME + '/frozen_inference_graph.pb'

# List of the strings that is used to add correct label for each box.
PATH_TO_LABELS = os.path.join('data', 'mscoco_label_map.pbtxt')

NUM_CLASSES = 90

# %% [markdown]
# ## Download Model

# %%
#opener = urllib.request.URLopener()
#opener.retrieve(DOWNLOAD_BASE + MODEL_FILE, MODEL_FILE)
#tar_file = tarfile.open(MODEL_FILE)
#for file in tar_file.getmembers():
#  file_name = os.path.basename(file.name)
#  if 'frozen_inference_graph.pb' in file_name:
#    tar_file.extract(file, os.getcwd())

# %% [markdown]
# ## Load a (frozen) Tensorflow model into memory.

# %%
detection_graph = tf.Graph()
with detection_graph.as_default():
  od_graph_def = tf.GraphDef()
  with tf.gfile.GFile(PATH_TO_CKPT, 'rb') as fid:
    serialized_graph = fid.read()
    od_graph_def.ParseFromString(serialized_graph)
    tf.import_graph_def(od_graph_def, name='')

# %% [markdown]
# ## Loading label map
# Label maps map indices to category names, so that when our convolution network predicts `5`, we know that this corresponds to `airplane`.  Here we use internal utility functions, but anything that returns a dictionary mapping integers to appropriate string labels would be fine

# %%
label_map = label_map_util.load_labelmap(PATH_TO_LABELS)
categories = label_map_util.convert_label_map_to_categories(label_map, max_num_classes=NUM_CLASSES, use_display_name=True)
category_index = label_map_util.create_category_index(categories)

# %% [markdown]
# ## Helper code

# %%
def load_image_into_numpy_array(image):
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape(
      (im_height, im_width, 3)).astype(np.uint8)

# %% [markdown]
# # Detection

# %%
# For the sake of simplicity we will use only 2 images:
# image1.jpg
# image2.jpg
# If you want to test the code with your images, just add path to the images to the TEST_IMAGE_PATHS.
PATH_TO_TEST_IMAGES_DIR = 'test_images'
TEST_IMAGE_PATHS = [ os.path.join(PATH_TO_TEST_IMAGES_DIR, 'image{}.jpg'.format(i)) for i in range(1, 3) ]

# Size, in inches, of the output images.
IMAGE_SIZE = (12, 8)

# Name of intermediate nodes for faster_rcnn_inception_v2
intermediate_nodes = ['FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_1a_7x7/BatchNorm/FusedBatchNorm:0',
                      'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_2b_1x1/BatchNorm/FusedBatchNorm:0',
                      'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_2c_3x3/BatchNorm/FusedBatchNorm:0',
                      'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/concat:0',
                      'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3c/concat:0',
                      'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_4a/concat:0',
                      'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_4b/concat:0',
                      'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_4c/concat:0',
                      'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_4d/concat:0',
                      'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_4e/concat:0',
                      'SecondStageFeatureExtractor/InceptionV2/Mixed_5a/concat:0',
                      'SecondStageFeatureExtractor/InceptionV2/Mixed_5b/concat:0',
                      'SecondStageFeatureExtractor/InceptionV2/Mixed_5c/concat:0',
                     ]

# %%
with detection_graph.as_default():
  with tf.Session(graph=detection_graph) as sess:
    # Print all tensors in detection_graph
    #for name in [n.name for n in tf.get_default_graph().as_graph_def().node]:
    #for n in [n for n in tf.get_default_graph().as_graph_def().node]:
    #  print (n.name, n)
    for i in tf.get_default_graph().get_operations():
      print (i.name, i.values())
    # Get intermediate nodes
    
    # Definite input and output Tensors for detection_graph
    image_tensor = detection_graph.get_tensor_by_name('image_tensor:0')
    # Each box represents a part of the image where a particular object was detected.
    detection_boxes = detection_graph.get_tensor_by_name('detection_boxes:0')
    # Each score represent how level of confidence for each of the objects.
    # Score is shown on the result image, together with the class label.
    detection_scores = detection_graph.get_tensor_by_name('detection_scores:0')
    detection_classes = detection_graph.get_tensor_by_name('detection_classes:0')
    num_detections = detection_graph.get_tensor_by_name('num_detections:0')
    for image_path in TEST_IMAGE_PATHS:
      image = Image.open(image_path)
      # the array based representation of the image will be used later in order to prepare the
      # result image with boxes and labels on it.
      image_np = load_image_into_numpy_array(image)
      # Expand dimensions since the model expects images to have shape: [1, None, None, 3]
      image_np_expanded = np.expand_dims(image_np, axis=0)
      # Actual detection.
      (boxes, scores, classes, num) = sess.run(
          [detection_boxes, detection_scores, detection_classes, num_detections],
          feed_dict={image_tensor: image_np_expanded})
      # Visualization of the results of a detection.
      vis_util.visualize_boxes_and_labels_on_image_array(
          image_np,
          np.squeeze(boxes),
          np.squeeze(classes).astype(np.int32),
          np.squeeze(scores),
          category_index,
          use_normalized_coordinates=True,
          line_thickness=8)
      plt.figure(figsize=IMAGE_SIZE)
      plt.imshow(image_np)
# Out:
# (u'Const', (<tf.Tensor 'Const:0' shape=(2,) dtype=float32>,))
# (u'Const_1', (<tf.Tensor 'Const_1:0' shape=(2,) dtype=float32>,))
# (u'Const_2', (<tf.Tensor 'Const_2:0' shape=(2,) dtype=float32>,))
# (u'image_tensor', (<tf.Tensor 'image_tensor:0' shape=(?, ?, ?, 3) dtype=uint8>,))
# (u'ToFloat', (<tf.Tensor 'ToFloat:0' shape=(?, ?, ?, 3) dtype=float32>,))
# (u'Preprocessor/map/Shape', (<tf.Tensor 'Preprocessor/map/Shape:0' shape=(4,) dtype=int32>,))
# (u'Preprocessor/map/strided_slice/stack', (<tf.Tensor 'Preprocessor/map/strided_slice/stack:0' shape=(1,) dtype=int32>,))
# (u'Preprocessor/map/strided_slice/stack_1', (<tf.Tensor 'Preprocessor/map/strided_slice/stack_1:0' shape=(1,) dtype=int32>,))
# (u'Preprocessor/map/strided_slice/stack_2', (<tf.Tensor 'Preprocessor/map/strided_slice/stack_2:0' shape=(1,) dtype=int32>,))
# (u'Preprocessor/map/strided_slice', (<tf.Tensor 'Preprocessor/map/strided_slice:0' shape=() dtype=int32>,))
# (u'Preprocessor/map/TensorArray', (<tf.Tensor 'Preprocessor/map/TensorArray:0' shape=(2,) dtype=resource>, <tf.Tensor 'Preprocessor/map/TensorArray:1' shape=() dtype=float32>))
# (u'Preprocessor/map/TensorArrayUnstack/Shape', (<tf.Tensor 'Preprocessor/map/TensorArrayUnstack/Shape:0' shape=(4,) dtype=int32>,))
# (u'Preprocessor/map/TensorArrayUnstack/strided_slice/stack', (<tf.Tensor 'Preprocessor/map/TensorArrayUnstack/strided_slice/stack:0' shape=(1,) dtype=int32>,))
# (u'Preprocessor/map/TensorArrayUnstack/strided_slice/stack_1', (<tf.Tensor 'Preprocessor/map/TensorArrayUnstack/strided_slice/stack_1:0' shape=(1,) dtype=int32>,))
# (u'Preprocessor/map/TensorArrayUnstack/strided_slice/stack_2', (<tf.Tensor 'Preprocessor/map/TensorArrayUnstack/strided_slice/stack_2:0' shape=(1,) dtype=int32>,))
# (u'Preprocessor/map/TensorArrayUnstack/strided_slice', (<tf.Tensor 'Preprocessor/map/TensorArrayUnstack/strided_slice:0' shape=() dtype=int32>,))
# (u'Preprocessor/map/TensorArrayUnstack/range/start', (<tf.Tensor 'Preprocessor/map/TensorArrayUnstack/range/start:0' shape=() dtype=int32>,))
# (u'Preprocessor/map/TensorArrayUnstack/range/delta', (<tf.Tensor 'Preprocessor/map/TensorArrayUnstack/range/delta:0' shape=() dtype=int32>,))
# (u'Preprocessor/map/TensorArrayUnstack/range', (<tf.Tensor 'Preprocessor/map/TensorArrayUnstack/range:0' shape=(?,) dtype=int32>,))
# (u'Preprocessor/map/TensorArrayUnstack/TensorArrayScatter/TensorArrayScatterV3', (<tf.Tensor 'Preprocessor/map/TensorArrayUnstack/TensorArrayScatter/TensorArrayScatterV3:0' shape=() dtype=float32>,))
# (u'Preprocessor/map/Const', (<tf.Tensor 'Preprocessor/map/Const:0' shape=() dtype=int32>,))
# (u'Preprocessor/map/TensorArray_1', (<tf.Tensor 'Preprocessor/map/TensorArray_1:0' shape=(2,) dtype=resource>, <tf.Tensor 'Preprocessor/map/TensorArray_1:1' shape=() dtype=float32>))
# (u'Preprocessor/map/while/Enter', (<tf.Tensor 'Preprocessor/map/while/Enter:0' shape=<unknown> dtype=int32>,))
# (u'Preprocessor/map/while/Enter_1', (<tf.Tensor 'Preprocessor/map/while/Enter_1:0' shape=<unknown> dtype=float32>,))
# (u'Preprocessor/map/while/Merge', (<tf.Tensor 'Preprocessor/map/while/Merge:0' shape=<unknown> dtype=int32>, <tf.Tensor 'Preprocessor/map/while/Merge:1' shape=() dtype=int32>))
# (u'Preprocessor/map/while/Merge_1', (<tf.Tensor 'Preprocessor/map/while/Merge_1:0' shape=<unknown> dtype=float32>, <tf.Tensor 'Preprocessor/map/while/Merge_1:1' shape=() dtype=int32>))
# (u'Preprocessor/map/while/Less/Enter', (<tf.Tensor 'Preprocessor/map/while/Less/Enter:0' shape=() dtype=int32>,))
# (u'Preprocessor/map/while/Less', (<tf.Tensor 'Preprocessor/map/while/Less:0' shape=<unknown> dtype=bool>,))
# (u'Preprocessor/map/while/LoopCond', (<tf.Tensor 'Preprocessor/map/while/LoopCond:0' shape=() dtype=bool>,))
# (u'Preprocessor/map/while/Switch', (<tf.Tensor 'Preprocessor/map/while/Switch:0' shape=<unknown> dtype=int32>, <tf.Tensor 'Preprocessor/map/while/Switch:1' shape=<unknown> dtype=int32>))
# (u'Preprocessor/map/while/Switch_1', (<tf.Tensor 'Preprocessor/map/while/Switch_1:0' shape=<unknown> dtype=float32>, <tf.Tensor 'Preprocessor/map/while/Switch_1:1' shape=<unknown> dtype=float32>))
# (u'Preprocessor/map/while/Identity', (<tf.Tensor 'Preprocessor/map/while/Identity:0' shape=<unknown> dtype=int32>,))
# (u'Preprocessor/map/while/Identity_1', (<tf.Tensor 'Preprocessor/map/while/Identity_1:0' shape=<unknown> dtype=float32>,))
# (u'Preprocessor/map/while/TensorArrayReadV3/Enter', (<tf.Tensor 'Preprocessor/map/while/TensorArrayReadV3/Enter:0' shape=(2,) dtype=resource>,))
# (u'Preprocessor/map/while/TensorArrayReadV3/Enter_1', (<tf.Tensor 'Preprocessor/map/while/TensorArrayReadV3/Enter_1:0' shape=() dtype=float32>,))
# (u'Preprocessor/map/while/TensorArrayReadV3', (<tf.Tensor 'Preprocessor/map/while/TensorArrayReadV3:0' shape=<unknown> dtype=float32>,))
# (u'Preprocessor/map/while/ResizeToRange/Shape', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/Shape:0' shape=(?,) dtype=int32>,))
# (u'Preprocessor/map/while/ResizeToRange/strided_slice/stack', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/strided_slice/stack:0' shape=(1,) dtype=int32>,))
# (u'Preprocessor/map/while/ResizeToRange/strided_slice/stack_1', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/strided_slice/stack_1:0' shape=(1,) dtype=int32>,))
# (u'Preprocessor/map/while/ResizeToRange/strided_slice/stack_2', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/strided_slice/stack_2:0' shape=(1,) dtype=int32>,))
# (u'Preprocessor/map/while/ResizeToRange/strided_slice', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/strided_slice:0' shape=() dtype=int32>,))
# (u'Preprocessor/map/while/ResizeToRange/ToFloat', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/ToFloat:0' shape=() dtype=float32>,))
# (u'Preprocessor/map/while/ResizeToRange/strided_slice_1/stack', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/strided_slice_1/stack:0' shape=(1,) dtype=int32>,))
# (u'Preprocessor/map/while/ResizeToRange/strided_slice_1/stack_1', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/strided_slice_1/stack_1:0' shape=(1,) dtype=int32>,))
# (u'Preprocessor/map/while/ResizeToRange/strided_slice_1/stack_2', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/strided_slice_1/stack_2:0' shape=(1,) dtype=int32>,))
# (u'Preprocessor/map/while/ResizeToRange/strided_slice_1', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/strided_slice_1:0' shape=() dtype=int32>,))
# (u'Preprocessor/map/while/ResizeToRange/ToFloat_1', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/ToFloat_1:0' shape=() dtype=float32>,))
# (u'Preprocessor/map/while/ResizeToRange/Minimum', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/Minimum:0' shape=() dtype=float32>,))
# (u'Preprocessor/map/while/ResizeToRange/Const', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/Const:0' shape=() dtype=float32>,))
# (u'Preprocessor/map/while/ResizeToRange/div', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/div:0' shape=() dtype=float32>,))
# (u'Preprocessor/map/while/ResizeToRange/mul', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/mul:0' shape=() dtype=float32>,))
# (u'Preprocessor/map/while/ResizeToRange/Round', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/Round:0' shape=() dtype=float32>,))
# (u'Preprocessor/map/while/ResizeToRange/ToInt32', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/ToInt32:0' shape=() dtype=int32>,))
# (u'Preprocessor/map/while/ResizeToRange/mul_1', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/mul_1:0' shape=() dtype=float32>,))
# (u'Preprocessor/map/while/ResizeToRange/Round_1', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/Round_1:0' shape=() dtype=float32>,))
# (u'Preprocessor/map/while/ResizeToRange/ToInt32_1', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/ToInt32_1:0' shape=() dtype=int32>,))
# (u'Preprocessor/map/while/ResizeToRange/stack', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/stack:0' shape=(2,) dtype=int32>,))
# (u'Preprocessor/map/while/ResizeToRange/Maximum', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/Maximum:0' shape=() dtype=float32>,))
# (u'Preprocessor/map/while/ResizeToRange/Const_1', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/Const_1:0' shape=() dtype=float32>,))
# (u'Preprocessor/map/while/ResizeToRange/div_1', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/div_1:0' shape=() dtype=float32>,))
# (u'Preprocessor/map/while/ResizeToRange/mul_2', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/mul_2:0' shape=() dtype=float32>,))
# (u'Preprocessor/map/while/ResizeToRange/Round_2', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/Round_2:0' shape=() dtype=float32>,))
# (u'Preprocessor/map/while/ResizeToRange/ToInt32_2', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/ToInt32_2:0' shape=() dtype=int32>,))
# (u'Preprocessor/map/while/ResizeToRange/mul_3', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/mul_3:0' shape=() dtype=float32>,))
# (u'Preprocessor/map/while/ResizeToRange/Round_3', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/Round_3:0' shape=() dtype=float32>,))
# (u'Preprocessor/map/while/ResizeToRange/ToInt32_3', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/ToInt32_3:0' shape=() dtype=int32>,))
# (u'Preprocessor/map/while/ResizeToRange/stack_1', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/stack_1:0' shape=(2,) dtype=int32>,))
# (u'Preprocessor/map/while/ResizeToRange/Const_2', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/Const_2:0' shape=(1,) dtype=int32>,))
# (u'Preprocessor/map/while/ResizeToRange/Max', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/Max:0' shape=() dtype=int32>,))
# (u'Preprocessor/map/while/ResizeToRange/ToFloat_2', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/ToFloat_2:0' shape=() dtype=float32>,))
# (u'Preprocessor/map/while/ResizeToRange/Greater', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/Greater:0' shape=() dtype=bool>,))
# (u'Preprocessor/map/while/ResizeToRange/cond/pred_id', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/cond/pred_id:0' shape=() dtype=bool>,))
# (u'Preprocessor/map/while/ResizeToRange/cond/Switch_1', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/cond/Switch_1:0' shape=(2,) dtype=int32>, <tf.Tensor 'Preprocessor/map/while/ResizeToRange/cond/Switch_1:1' shape=(2,) dtype=int32>))
# (u'Preprocessor/map/while/ResizeToRange/cond/Switch_2', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/cond/Switch_2:0' shape=(2,) dtype=int32>, <tf.Tensor 'Preprocessor/map/while/ResizeToRange/cond/Switch_2:1' shape=(2,) dtype=int32>))
# (u'Preprocessor/map/while/ResizeToRange/cond/Merge', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/cond/Merge:0' shape=(2,) dtype=int32>, <tf.Tensor 'Preprocessor/map/while/ResizeToRange/cond/Merge:1' shape=() dtype=int32>))
# (u'Preprocessor/map/while/ResizeToRange/ExpandDims/dim', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/ExpandDims/dim:0' shape=() dtype=int32>,))
# (u'Preprocessor/map/while/ResizeToRange/ExpandDims', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/ExpandDims:0' shape=<unknown> dtype=float32>,))
# (u'Preprocessor/map/while/ResizeToRange/ResizeBilinear', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/ResizeBilinear:0' shape=(?, ?, ?, ?) dtype=float32>,))
# (u'Preprocessor/map/while/ResizeToRange/Squeeze', (<tf.Tensor 'Preprocessor/map/while/ResizeToRange/Squeeze:0' shape=(?, ?, ?) dtype=float32>,))
# (u'Preprocessor/map/while/TensorArrayWrite/TensorArrayWriteV3/Enter', (<tf.Tensor 'Preprocessor/map/while/TensorArrayWrite/TensorArrayWriteV3/Enter:0' shape=(2,) dtype=resource>,))
# (u'Preprocessor/map/while/TensorArrayWrite/TensorArrayWriteV3', (<tf.Tensor 'Preprocessor/map/while/TensorArrayWrite/TensorArrayWriteV3:0' shape=() dtype=float32>,))
# (u'Preprocessor/map/while/add/y', (<tf.Tensor 'Preprocessor/map/while/add/y:0' shape=() dtype=int32>,))
# (u'Preprocessor/map/while/add', (<tf.Tensor 'Preprocessor/map/while/add:0' shape=<unknown> dtype=int32>,))
# (u'Preprocessor/map/while/NextIteration', (<tf.Tensor 'Preprocessor/map/while/NextIteration:0' shape=<unknown> dtype=int32>,))
# (u'Preprocessor/map/while/NextIteration_1', (<tf.Tensor 'Preprocessor/map/while/NextIteration_1:0' shape=() dtype=float32>,))
# (u'Preprocessor/map/while/Exit_1', (<tf.Tensor 'Preprocessor/map/while/Exit_1:0' shape=<unknown> dtype=float32>,))
# (u'Preprocessor/map/TensorArrayStack/TensorArraySizeV3', (<tf.Tensor 'Preprocessor/map/TensorArrayStack/TensorArraySizeV3:0' shape=() dtype=int32>,))
# (u'Preprocessor/map/TensorArrayStack/range/start', (<tf.Tensor 'Preprocessor/map/TensorArrayStack/range/start:0' shape=() dtype=int32>,))
# (u'Preprocessor/map/TensorArrayStack/range/delta', (<tf.Tensor 'Preprocessor/map/TensorArrayStack/range/delta:0' shape=() dtype=int32>,))
# (u'Preprocessor/map/TensorArrayStack/range', (<tf.Tensor 'Preprocessor/map/TensorArrayStack/range:0' shape=(?,) dtype=int32>,))
# (u'Preprocessor/map/TensorArrayStack/TensorArrayGatherV3', (<tf.Tensor 'Preprocessor/map/TensorArrayStack/TensorArrayGatherV3:0' shape=<unknown> dtype=float32>,))
# (u'Preprocessor/mul/x', (<tf.Tensor 'Preprocessor/mul/x:0' shape=() dtype=float32>,))
# (u'Preprocessor/mul', (<tf.Tensor 'Preprocessor/mul:0' shape=<unknown> dtype=float32>,))
# (u'Preprocessor/sub/y', (<tf.Tensor 'Preprocessor/sub/y:0' shape=() dtype=float32>,))
# (u'Preprocessor/sub', (<tf.Tensor 'Preprocessor/sub:0' shape=<unknown> dtype=float32>,))
# (u'Shape', (<tf.Tensor 'Shape:0' shape=(?,) dtype=int32>,))
# (u'FirstStageFeatureExtractor/Shape', (<tf.Tensor 'FirstStageFeatureExtractor/Shape:0' shape=(?,) dtype=int32>,))
# (u'FirstStageFeatureExtractor/strided_slice/stack', (<tf.Tensor 'FirstStageFeatureExtractor/strided_slice/stack:0' shape=(1,) dtype=int32>,))
# (u'FirstStageFeatureExtractor/strided_slice/stack_1', (<tf.Tensor 'FirstStageFeatureExtractor/strided_slice/stack_1:0' shape=(1,) dtype=int32>,))
# (u'FirstStageFeatureExtractor/strided_slice/stack_2', (<tf.Tensor 'FirstStageFeatureExtractor/strided_slice/stack_2:0' shape=(1,) dtype=int32>,))
# (u'FirstStageFeatureExtractor/strided_slice', (<tf.Tensor 'FirstStageFeatureExtractor/strided_slice:0' shape=() dtype=int32>,))
# (u'FirstStageFeatureExtractor/GreaterEqual/y', (<tf.Tensor 'FirstStageFeatureExtractor/GreaterEqual/y:0' shape=() dtype=int32>,))
# (u'FirstStageFeatureExtractor/GreaterEqual', (<tf.Tensor 'FirstStageFeatureExtractor/GreaterEqual:0' shape=() dtype=bool>,))
# (u'FirstStageFeatureExtractor/Shape_1', (<tf.Tensor 'FirstStageFeatureExtractor/Shape_1:0' shape=(?,) dtype=int32>,))
# (u'FirstStageFeatureExtractor/strided_slice_1/stack', (<tf.Tensor 'FirstStageFeatureExtractor/strided_slice_1/stack:0' shape=(1,) dtype=int32>,))
# (u'FirstStageFeatureExtractor/strided_slice_1/stack_1', (<tf.Tensor 'FirstStageFeatureExtractor/strided_slice_1/stack_1:0' shape=(1,) dtype=int32>,))
# (u'FirstStageFeatureExtractor/strided_slice_1/stack_2', (<tf.Tensor 'FirstStageFeatureExtractor/strided_slice_1/stack_2:0' shape=(1,) dtype=int32>,))
# (u'FirstStageFeatureExtractor/strided_slice_1', (<tf.Tensor 'FirstStageFeatureExtractor/strided_slice_1:0' shape=() dtype=int32>,))
# (u'FirstStageFeatureExtractor/GreaterEqual_1/y', (<tf.Tensor 'FirstStageFeatureExtractor/GreaterEqual_1/y:0' shape=() dtype=int32>,))
# (u'FirstStageFeatureExtractor/GreaterEqual_1', (<tf.Tensor 'FirstStageFeatureExtractor/GreaterEqual_1:0' shape=() dtype=bool>,))
# (u'FirstStageFeatureExtractor/LogicalAnd', (<tf.Tensor 'FirstStageFeatureExtractor/LogicalAnd:0' shape=() dtype=bool>,))
# (u'FirstStageFeatureExtractor/Assert/Assert/data_0', (<tf.Tensor 'FirstStageFeatureExtractor/Assert/Assert/data_0:0' shape=() dtype=string>,))
# (u'FirstStageFeatureExtractor/Assert/Assert', ())
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/depthwise_weights', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/depthwise_weights:0' shape=(7, 7, 3, 8) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/depthwise_weights/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/depthwise_weights/read:0' shape=(7, 7, 3, 8) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/pointwise_weights', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/pointwise_weights:0' shape=(1, 1, 24, 64) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/pointwise_weights/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/pointwise_weights/read:0' shape=(1, 1, 24, 64) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_1a_7x7/separable_conv2d/depthwise', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_1a_7x7/separable_conv2d/depthwise:0' shape=(?, ?, ?, 24) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_1a_7x7/separable_conv2d', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_1a_7x7/separable_conv2d:0' shape=(?, ?, ?, 64) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/BatchNorm/gamma', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/BatchNorm/gamma:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/BatchNorm/gamma/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/BatchNorm/gamma/read:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/BatchNorm/beta', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/BatchNorm/beta:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/BatchNorm/beta/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/BatchNorm/beta/read:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/BatchNorm/moving_mean', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/BatchNorm/moving_mean:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/BatchNorm/moving_mean/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/BatchNorm/moving_mean/read:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/BatchNorm/moving_variance', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/BatchNorm/moving_variance:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/BatchNorm/moving_variance/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_1a_7x7/BatchNorm/moving_variance/read:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_1a_7x7/BatchNorm/FusedBatchNorm', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_1a_7x7/BatchNorm/FusedBatchNorm:0' shape=(?, ?, ?, 64) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_1a_7x7/BatchNorm/FusedBatchNorm:1' shape=(64,) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_1a_7x7/BatchNorm/FusedBatchNorm:2' shape=(64,) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_1a_7x7/BatchNorm/FusedBatchNorm:3' shape=(64,) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_1a_7x7/BatchNorm/FusedBatchNorm:4' shape=(64,) dtype=float32>))
# (u'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_1a_7x7/Relu', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_1a_7x7/Relu:0' shape=(?, ?, ?, 64) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/InceptionV2/MaxPool_2a_3x3/MaxPool', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/MaxPool_2a_3x3/MaxPool:0' shape=(?, ?, ?, 64) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_2b_1x1/weights', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_2b_1x1/weights:0' shape=(1, 1, 64, 64) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_2b_1x1/weights/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_2b_1x1/weights/read:0' shape=(1, 1, 64, 64) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_2b_1x1/Conv2D', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_2b_1x1/Conv2D:0' shape=(?, ?, ?, 64) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_2b_1x1/BatchNorm/gamma', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_2b_1x1/BatchNorm/gamma:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_2b_1x1/BatchNorm/gamma/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_2b_1x1/BatchNorm/gamma/read:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_2b_1x1/BatchNorm/beta', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_2b_1x1/BatchNorm/beta:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_2b_1x1/BatchNorm/beta/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_2b_1x1/BatchNorm/beta/read:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_2b_1x1/BatchNorm/moving_mean', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_2b_1x1/BatchNorm/moving_mean:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_2b_1x1/BatchNorm/moving_mean/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_2b_1x1/BatchNorm/moving_mean/read:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_2b_1x1/BatchNorm/moving_variance', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_2b_1x1/BatchNorm/moving_variance:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_2b_1x1/BatchNorm/moving_variance/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_2b_1x1/BatchNorm/moving_variance/read:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_2b_1x1/BatchNorm/FusedBatchNorm', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_2b_1x1/BatchNorm/FusedBatchNorm:0' shape=(?, ?, ?, 64) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_2b_1x1/BatchNorm/FusedBatchNorm:1' shape=(64,) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_2b_1x1/BatchNorm/FusedBatchNorm:2' shape=(64,) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_2b_1x1/BatchNorm/FusedBatchNorm:3' shape=(64,) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_2b_1x1/BatchNorm/FusedBatchNorm:4' shape=(64,) dtype=float32>))
# (u'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_2b_1x1/Relu', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_2b_1x1/Relu:0' shape=(?, ?, ?, 64) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_2c_3x3/weights', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_2c_3x3/weights:0' shape=(3, 3, 64, 192) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_2c_3x3/weights/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_2c_3x3/weights/read:0' shape=(3, 3, 64, 192) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_2c_3x3/Conv2D', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_2c_3x3/Conv2D:0' shape=(?, ?, ?, 192) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_2c_3x3/BatchNorm/gamma', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_2c_3x3/BatchNorm/gamma:0' shape=(192,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_2c_3x3/BatchNorm/gamma/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_2c_3x3/BatchNorm/gamma/read:0' shape=(192,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_2c_3x3/BatchNorm/beta', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_2c_3x3/BatchNorm/beta:0' shape=(192,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_2c_3x3/BatchNorm/beta/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_2c_3x3/BatchNorm/beta/read:0' shape=(192,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_2c_3x3/BatchNorm/moving_mean', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_2c_3x3/BatchNorm/moving_mean:0' shape=(192,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_2c_3x3/BatchNorm/moving_mean/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_2c_3x3/BatchNorm/moving_mean/read:0' shape=(192,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_2c_3x3/BatchNorm/moving_variance', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_2c_3x3/BatchNorm/moving_variance:0' shape=(192,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Conv2d_2c_3x3/BatchNorm/moving_variance/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Conv2d_2c_3x3/BatchNorm/moving_variance/read:0' shape=(192,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_2c_3x3/BatchNorm/FusedBatchNorm', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_2c_3x3/BatchNorm/FusedBatchNorm:0' shape=(?, ?, ?, 192) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_2c_3x3/BatchNorm/FusedBatchNorm:1' shape=(192,) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_2c_3x3/BatchNorm/FusedBatchNorm:2' shape=(192,) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_2c_3x3/BatchNorm/FusedBatchNorm:3' shape=(192,) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_2c_3x3/BatchNorm/FusedBatchNorm:4' shape=(192,) dtype=float32>))
# (u'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_2c_3x3/Relu', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Conv2d_2c_3x3/Relu:0' shape=(?, ?, ?, 192) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/InceptionV2/MaxPool_3a_3x3/MaxPool', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/MaxPool_3a_3x3/MaxPool:0' shape=(?, ?, ?, 192) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/weights', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/weights:0' shape=(1, 1, 192, 64) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/weights/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/weights/read:0' shape=(1, 1, 192, 64) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/Conv2D', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/Conv2D:0' shape=(?, ?, ?, 64) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/BatchNorm/gamma', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/BatchNorm/gamma:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/BatchNorm/gamma/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/BatchNorm/gamma/read:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/BatchNorm/beta', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/BatchNorm/beta:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/BatchNorm/beta/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/BatchNorm/beta/read:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/BatchNorm/moving_mean', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/BatchNorm/moving_mean:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/BatchNorm/moving_mean/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/BatchNorm/moving_mean/read:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/BatchNorm/moving_variance', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/BatchNorm/moving_variance:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/BatchNorm/moving_variance/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/BatchNorm/moving_variance/read:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/BatchNorm/FusedBatchNorm', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/BatchNorm/FusedBatchNorm:0' shape=(?, ?, ?, 64) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/BatchNorm/FusedBatchNorm:1' shape=(64,) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/BatchNorm/FusedBatchNorm:2' shape=(64,) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/BatchNorm/FusedBatchNorm:3' shape=(64,) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/BatchNorm/FusedBatchNorm:4' shape=(64,) dtype=float32>))
# (u'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/Relu', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_0/Conv2d_0a_1x1/Relu:0' shape=(?, ?, ?, 64) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/weights', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/weights:0' shape=(1, 1, 192, 64) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/weights/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/weights/read:0' shape=(1, 1, 192, 64) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/Conv2D', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/Conv2D:0' shape=(?, ?, ?, 64) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/BatchNorm/gamma', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/BatchNorm/gamma:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/BatchNorm/gamma/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/BatchNorm/gamma/read:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/BatchNorm/beta', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/BatchNorm/beta:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/BatchNorm/beta/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/BatchNorm/beta/read:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/BatchNorm/moving_mean', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/BatchNorm/moving_mean:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/BatchNorm/moving_mean/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/BatchNorm/moving_mean/read:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/BatchNorm/moving_variance', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/BatchNorm/moving_variance:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/BatchNorm/moving_variance/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/BatchNorm/moving_variance/read:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/BatchNorm/FusedBatchNorm', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/BatchNorm/FusedBatchNorm:0' shape=(?, ?, ?, 64) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/BatchNorm/FusedBatchNorm:1' shape=(64,) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/BatchNorm/FusedBatchNorm:2' shape=(64,) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/BatchNorm/FusedBatchNorm:3' shape=(64,) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/BatchNorm/FusedBatchNorm:4' shape=(64,) dtype=float32>))
# (u'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/Relu', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_1/Conv2d_0a_1x1/Relu:0' shape=(?, ?, ?, 64) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/weights', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/weights:0' shape=(3, 3, 64, 64) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/weights/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/weights/read:0' shape=(3, 3, 64, 64) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/Conv2D', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/Conv2D:0' shape=(?, ?, ?, 64) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/BatchNorm/gamma', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/BatchNorm/gamma:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/BatchNorm/gamma/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/BatchNorm/gamma/read:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/BatchNorm/beta', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/BatchNorm/beta:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/BatchNorm/beta/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/BatchNorm/beta/read:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/BatchNorm/moving_mean', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/BatchNorm/moving_mean:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/BatchNorm/moving_mean/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/BatchNorm/moving_mean/read:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/BatchNorm/moving_variance', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/BatchNorm/moving_variance:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/BatchNorm/moving_variance/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/BatchNorm/moving_variance/read:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/BatchNorm/FusedBatchNorm', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/BatchNorm/FusedBatchNorm:0' shape=(?, ?, ?, 64) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/BatchNorm/FusedBatchNorm:1' shape=(64,) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/BatchNorm/FusedBatchNorm:2' shape=(64,) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/BatchNorm/FusedBatchNorm:3' shape=(64,) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/BatchNorm/FusedBatchNorm:4' shape=(64,) dtype=float32>))
# (u'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/Relu', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_1/Conv2d_0b_3x3/Relu:0' shape=(?, ?, ?, 64) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/weights', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/weights:0' shape=(1, 1, 192, 64) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/weights/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/weights/read:0' shape=(1, 1, 192, 64) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/Conv2D', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/Conv2D:0' shape=(?, ?, ?, 64) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/BatchNorm/gamma', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/BatchNorm/gamma:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/BatchNorm/gamma/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/BatchNorm/gamma/read:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/BatchNorm/beta', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/BatchNorm/beta:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/BatchNorm/beta/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/BatchNorm/beta/read:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/BatchNorm/moving_mean', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/BatchNorm/moving_mean:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/BatchNorm/moving_mean/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/BatchNorm/moving_mean/read:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/BatchNorm/moving_variance', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/BatchNorm/moving_variance:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/BatchNorm/moving_variance/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/BatchNorm/moving_variance/read:0' shape=(64,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/BatchNorm/FusedBatchNorm', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/BatchNorm/FusedBatchNorm:0' shape=(?, ?, ?, 64) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/BatchNorm/FusedBatchNorm:1' shape=(64,) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/BatchNorm/FusedBatchNorm:2' shape=(64,) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/BatchNorm/FusedBatchNorm:3' shape=(64,) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/BatchNorm/FusedBatchNorm:4' shape=(64,) dtype=float32>))
# (u'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/Relu', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_2/Conv2d_0a_1x1/Relu:0' shape=(?, ?, ?, 64) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/weights', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/weights:0' shape=(3, 3, 64, 96) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/weights/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/weights/read:0' shape=(3, 3, 64, 96) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/Conv2D', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/Conv2D:0' shape=(?, ?, ?, 96) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/BatchNorm/gamma', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/BatchNorm/gamma:0' shape=(96,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/BatchNorm/gamma/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/BatchNorm/gamma/read:0' shape=(96,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/BatchNorm/beta', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/BatchNorm/beta:0' shape=(96,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/BatchNorm/beta/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/BatchNorm/beta/read:0' shape=(96,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/BatchNorm/moving_mean', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/BatchNorm/moving_mean:0' shape=(96,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/BatchNorm/moving_mean/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/BatchNorm/moving_mean/read:0' shape=(96,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/BatchNorm/moving_variance', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/BatchNorm/moving_variance:0' shape=(96,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/BatchNorm/moving_variance/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/BatchNorm/moving_variance/read:0' shape=(96,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/BatchNorm/FusedBatchNorm', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/BatchNorm/FusedBatchNorm:0' shape=(?, ?, ?, 96) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/BatchNorm/FusedBatchNorm:1' shape=(96,) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/BatchNorm/FusedBatchNorm:2' shape=(96,) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/BatchNorm/FusedBatchNorm:3' shape=(96,) dtype=float32>, <tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/BatchNorm/FusedBatchNorm:4' shape=(96,) dtype=float32>))
# (u'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/Relu', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/Relu:0' shape=(?, ?, ?, 96) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0c_3x3/weights', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0c_3x3/weights:0' shape=(3, 3, 96, 96) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0c_3x3/weights/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0c_3x3/weights/read:0' shape=(3, 3, 96, 96) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_2/Conv2d_0c_3x3/Conv2D', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_2/Conv2d_0c_3x3/Conv2D:0' shape=(?, ?, ?, 96) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0c_3x3/BatchNorm/gamma', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0c_3x3/BatchNorm/gamma:0' shape=(96,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0c_3x3/BatchNorm/gamma/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0c_3x3/BatchNorm/gamma/read:0' shape=(96,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0c_3x3/BatchNorm/beta', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0c_3x3/BatchNorm/beta:0' shape=(96,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0c_3x3/BatchNorm/beta/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0c_3x3/BatchNorm/beta/read:0' shape=(96,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0c_3x3/BatchNorm/moving_mean', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0c_3x3/BatchNorm/moving_mean:0' shape=(96,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0c_3x3/BatchNorm/moving_mean/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0c_3x3/BatchNorm/moving_mean/read:0' shape=(96,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0c_3x3/BatchNorm/moving_variance', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0c_3x3/BatchNorm/moving_variance:0' shape=(96,) dtype=float32>,))
# (u'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0c_3x3/BatchNorm/moving_variance/read', (<tf.Tensor 'FirstStageFeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0c_3x3/BatchNorm/moving_variance/read:0' shape=(96,) dtype=float32>,))
# ...
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ClipToWindow_49/Area/Squeeze', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ClipToWindow_49/Area/Squeeze:0' shape=(?,) dtype=float32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ClipToWindow_49/Greater/y', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ClipToWindow_49/Greater/y:0' shape=() dtype=float32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ClipToWindow_49/Greater', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ClipToWindow_49/Greater:0' shape=(?,) dtype=bool>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ClipToWindow_49/Where', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ClipToWindow_49/Where:0' shape=(?, 1) dtype=int64>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ClipToWindow_49/Reshape/shape', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ClipToWindow_49/Reshape/shape:0' shape=(1,) dtype=int32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ClipToWindow_49/Reshape', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ClipToWindow_49/Reshape:0' shape=(?,) dtype=int64>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ClipToWindow_49/Cast', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ClipToWindow_49/Cast:0' shape=(?,) dtype=int32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ClipToWindow_49/Gather/Gather', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ClipToWindow_49/Gather/Gather:0' shape=(?, 4) dtype=float32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ClipToWindow_49/Gather/Gather_2', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ClipToWindow_49/Gather/Gather_2:0' shape=(?,) dtype=float32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice/stack', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice/stack:0' shape=(1,) dtype=int32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice/stack_1', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice/stack_1:0' shape=(1,) dtype=int32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice/stack_2', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice/stack_2:0' shape=(1,) dtype=int32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice:0' shape=() dtype=float32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_1/stack', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_1/stack:0' shape=(1,) dtype=int32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_1/stack_1', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_1/stack_1:0' shape=(1,) dtype=int32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_1/stack_2', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_1/stack_2:0' shape=(1,) dtype=int32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_1', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_1:0' shape=() dtype=float32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/sub', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/sub:0' shape=() dtype=float32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_2/stack', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_2/stack:0' shape=(1,) dtype=int32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_2/stack_1', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_2/stack_1:0' shape=(1,) dtype=int32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_2/stack_2', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_2/stack_2:0' shape=(1,) dtype=int32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_2', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_2:0' shape=() dtype=float32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_3/stack', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_3/stack:0' shape=(1,) dtype=int32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_3/stack_1', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_3/stack_1:0' shape=(1,) dtype=int32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_3/stack_2', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_3/stack_2:0' shape=(1,) dtype=int32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_3', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_3:0' shape=() dtype=float32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/sub_1', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/sub_1:0' shape=() dtype=float32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_4/stack', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_4/stack:0' shape=(1,) dtype=int32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_4/stack_1', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_4/stack_1:0' shape=(1,) dtype=int32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_4/stack_2', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_4/stack_2:0' shape=(1,) dtype=int32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_4', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_4:0' shape=() dtype=float32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_5/stack', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_5/stack:0' shape=(1,) dtype=int32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_5/stack_1', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_5/stack_1:0' shape=(1,) dtype=int32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_5/stack_2', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_5/stack_2:0' shape=(1,) dtype=int32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_5', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_5:0' shape=() dtype=float32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_6/stack', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_6/stack:0' shape=(1,) dtype=int32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_6/stack_1', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_6/stack_1:0' shape=(1,) dtype=int32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_6/stack_2', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_6/stack_2:0' shape=(1,) dtype=int32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_6', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_6:0' shape=() dtype=float32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_7/stack', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_7/stack:0' shape=(1,) dtype=int32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_7/stack_1', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_7/stack_1:0' shape=(1,) dtype=int32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_7/stack_2', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_7/stack_2:0' shape=(1,) dtype=int32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_7', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/strided_slice_7:0' shape=() dtype=float32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/sub_2/y', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/sub_2/y:0' shape=(4,) dtype=float32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/sub_2', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/sub_2:0' shape=(?, 4) dtype=float32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/div/x', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/div/x:0' shape=() dtype=float32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/div', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/div:0' shape=() dtype=float32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/div_1/x', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/div_1/x:0' shape=() dtype=float32>,))
# (u'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/div_1', (<tf.Tensor 'SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame_49/div_1:0' shape=() dtype=float32>,))
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
